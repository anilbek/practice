# %%
import modin.pandas as pd
from modin.config import ProgressBar

ProgressBar.enable()
import ray

ray.init() # Start the Ray runtime for single-node
# Out:
# 2024-08-19 17:37:10,494	INFO worker.py:1633 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.17', ray_version='2.7.0', ray_commit='b4bba4717f5ba04ee25580fe8f88eed63ef0c5dc', protocol_version=None)

# %%
df_fake = pd.read_csv("fake.csv", nrows=10)
df_true = pd.read_csv("true.csv", nrows=10)

# %%
df_fake
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
df_true
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
df_fake.drop(columns=df_fake.columns[2:4].tolist(), inplace=True)

# %%
df_true.drop(columns=df_true.columns[2:4].tolist(), inplace=True)

# %%
df_fake["target"] = 0
df_true["target"] = 1
# Out:
# Estimated completion of line 1:   0%           Elapsed time: 00:00, estimated remaining time: ?
# Estimated completion of line 2:   0%           Elapsed time: 00:00, estimated remaining time: ?

# %%
df = pd.concat([df_fake, df_true], ignore_index=True)
df
# Out:
#                                                 title  \
# 0    Donald Trump Sends Out Embarrassing New Year’...
# 1    Drunk Bragging Trump Staffer Started Russian ...
# 2    Sheriff David Clarke Becomes An Internet Joke...
# 3    Trump Is So Obsessed He Even Has Obama’s Name...
# 4    Pope Francis Just Called Out Donald Trump Dur...
# 5    Racist Alabama Cops Brutalize Black Boy While...
# 6    Fresh Off The Golf Course, Trump Lashes Out A...
# 7    Trump Said Some INSANELY Racist Stuff Inside ...
# 8    Former CIA Director Slams Trump Over UN Bully...
# 9    WATCH: Brand-New Pro-Trump Ad Features So Muc...
# 10  As U.S. budget fight looms, Republicans flip t...
# 11  U.S. military to accept transgender recruits o...
# 12  Senior U.S. Republican senator: 'Let Mr. Muell...
# 13  FBI Russia probe helped by Australian diplomat...
# 14  Trump wants Postal Service to charge 'much mor...
# 15  White House, Congress prepare for talks on spe...
# ...

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import SnowballStemmer
from autocorrect import Speller
from string import punctuation
import string

stop_words = set(stopwords.words("english"))
spell = Speller(lang="en")
stemmer = SnowballStemmer("english")
punctuation += "’"


def preprocess_corpus(text):
    
    tokens = word_tokenize(text)
    tokens = [token.lower() for token in tokens]
    tokens = [spell(token) for token in tokens]
    tokens = [token for token in tokens if token not in punctuation]
    tokens = [token for token in tokens if token not in stop_words]
    tokens = [token for token in tokens if not token.isdigit()]
    tokens = [stemmer.stem(token) for token in tokens]
    return tokens

# %%
new_df = pd.DataFrame(columns=["title", "text"])
# Out:
# ...
# Distributing Dataframe:   0%           Elapsed time: 00:00, estimated remaining time: ?

# %%
new_df["title"] = df["title"].map(preprocess_corpus)
# Out:
# ...
# Estimated completion of line 1:   0%           Elapsed time: 00:00, estimated remaining time: ?

# %%
new_df["text"] = df["text"].map(preprocess_corpus)
# Out:
# Estimated completion of line 1:   0%           Elapsed time: 00:00, estimated remaining time: ?

# %%
new_df
# Out:
#                                                 title  \
# 0   [donald, trump, send, embarrass, new, year, ev...
# 1   [drunk, brag, trump, staffer, start, russian, ...
# 2   [sheriff, david, clark, becom, internet, joke,...
# 3   [trump, obsess, even, obama, name, code, websi...
# 4   [pope, franci, call, donald, trump, christma, ...
# 5   [racist, alabama, cop, brutal, black, boy, han...
# 6   [fresh, golf, cours, trump, lash, fbi, deputi,...
# 7   [trump, said, instant, racist, stuff, insid, o...
# 8   [former, cia, director, slam, trump, un, bulli...
# 9   [watch, brand-new, pro-trump, ad, featur, much...
# 10  [u.s., budget, fight, loom, republican, flip, ...
# 11  [u.s., militari, accept, transgend, recruit, m...
# 12  [senior, u.s., republican, senat, let, mr., mu...
# 13  [fbi, russia, probe, help, australian, diploma...
# 14  [trump, want, postal, servic, charg, much, ama...
# 15  [white, hous, congress, prepar, talk, spend, i...
# ...

# %%
from sklearn.model_selection import train_test_split

X = new_df[['title', 'text']].values
y = df[['target']].values

X_train, X_valid_test, y_train, y_valid_test = train_test_split(
    X, y, test_size=0.33, shuffle = True, random_state=42)

X_valid, X_test, y_valid, y_test = train_test_split(
    X_valid_test, y_valid_test, test_size=0.5, shuffle = True, random_state=42)

# %%
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec
import numpy as np

# %%
d2v_train_title = [TaggedDocument(doc, ["train_title_" + str(i)]) for i, doc in enumerate(X_train[:,0].tolist())]
d2v_train_text = [TaggedDocument(doc, ["train_text_" + str(i)]) for i, doc in enumerate(X_train[:,1].tolist())]

# %%
train_title_model = Doc2Vec(vector_size=100, min_count=2, epochs=10)
train_title_model.build_vocab(d2v_train_title)
train_title_model.train(d2v_train_title, total_examples=model.corpus_count, epochs=model.epochs)

train_text_model = Doc2Vec(vector_size=100, min_count=2, epochs=10)
train_text_model.build_vocab(d2v_train_text)
train_text_model.train(d2v_train_text, total_examples=model.corpus_count, epochs=model.epochs)

# %%
X_train_title_vectors = [train_title_model.infer_vector(doc, steps = 5) for doc in X_train[:,0]]
X_train_text_vectors = [train_text_model.infer_vector(doc, steps = 5) for doc in X_train[:,1]]
X_train_vectors = np.hstack((X_train_title_vectors, X_train_text_vectors))

X_valid_title_vectors = [train_title_model.infer_vector(doc, steps = 5) for doc in X_valid[:,0]]
X_valid_text_vectors = [train_text_model.infer_vector(doc, steps = 5) for doc in X_valid[:,1]]
X_valid_vectors = np.hstack((X_valid_title_vectors, X_valid_text_vectors))

X_test_title_vectors = [train_title_model.infer_vector(doc, steps = 5) for doc in X_test[:,0]]
X_test_text_vectors = [train_text_model.infer_vector(doc, steps = 5) for doc in X_test[:,1]]
X_test_vectors = np.hstack((X_test_title_vectors, X_test_text_vectors))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train_vectors)
X_train_vectors_scaled = scaler.transform(X_train_vectors)
X_valid_vectors_scaled = scaler.transform(X_valid_vectors)
X_test_vectors_scaled = scaler.transform(X_test_vectors)

# %%
from sklearn.decomposition import PCA

# for simplicity, omit using cross validation with an estimator. Instead use elbow method to select the optimal number of PCA components 
pca = PCA(n_components=None)
pca.fit(X_train_vectors_scaled)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title('Percentage of Variance Explained')
plt.xlabel('Number of Components')
plt.ylabel('Percentage of Variance Explained')
plt.show()

# %%
# use ? pca components
pca = PCA(n_components = )
pca.fit(X_train_vectors_scaled)
X_train_pca = pca.transform(X_train_vectors_scaled)
X_valid_pca = pca.transform(X_valid_vectors_scaled)
X_test_pca = pca.transform(X_test_vectors_scaled)

# %% [markdown]
# ## now do xgboost like in fake news detection.ipynb
